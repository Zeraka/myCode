# %%
file = open("hero.txt", mode = "r")
i = 0
while(i < 9):
    print(file.readline())
    i += 1
    
#fp = file.readline()
#print(file)

file.close()

# %%
file = open("hero.txt", mode = "r+")
newFile  = open("heroDone.txt",mode = "a+")#以追加模式打开文件，并且把文件指针移动到末尾
flag = 0
#txt里面的字符都是字符串形式，而没有数字，需要进行处理
ids = []
#去除双引号以及逗号
while(1):
    str = file.readline()
    #把文件里的逗号改为\t并且切分
    str = str.replace("\"", "").replace(",","\t")
    #print(str)
    #把字符串输入到新的文件中，当然是按照userID
    strs = str.split('\t')
    id = strs[3]#把字符变为数字
   
    if(flag == 0):
        flag = 1
        #如果不存在该文件，则创建一个
    if(flag and id):
        fileName = "userId" + id +".txt"
        open(fileName, mode="a")
        
        
        #降序排列
    #一旦没有的话，就创建一个文件，并且把东西写入文件
    print(strs)
    #newFile.write(str)
    if(not str):
        break
file.close()


#把每个ID都排好序

#把每个ID的胜率排前10的英雄列出来
#把每个ID的

newFile.close()


#每个ID成功次数排前十的英雄，并且变为一个表格

#每个ID成功次数排前十
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-1820ed311fb4> in <module>
# ----> 1 file = open("hero.txt", mode = "r+")
#       2 newFile  = open("heroDone.txt",mode = "a+")#以追加模式打开文件，并且把文件指针移动到末尾
#       3 flag = 0
#       4 #txt里面的字符都是字符串形式，而没有数字，需要进行处理
#       5 ids = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hero.txt'

# %%
#replace函数的使用
str = "\"Fiddlesticks,0\"	4	98"
print(str)
str2=str.replace("\"", "").replace(",", "\t")
str3 = str2.split("\t")
print(str2)
print(str3)

# %%
file = open("heroDone.txt", mode = "r+")
flag = 0
ids = []

while(1):
    str = file.readline().replace("\"", "").replace(",","\t")
    strs = str.split('\t')
    id = strs[3]
    
    strs = str.split('\t')
    id = strs[3]
    
    if(flag == 0):
        flag = 1
        
    if(flag and id):
        fileName = "userId" + id 
        open(fileName, mode="a")
        
        
        #降序排列
    #一旦没有的话，就创建一个文件，并且把东西写入文件
    print(strs)
    #newFile.write(str)
    if(not str):
        break
file.close()


#把每个ID都排好序

#把每个ID的胜率排前10的英雄列出来
#把每个ID的

newFile.close()


#每个ID成功次数排前十的英雄，并且变为一个表格

#每个ID成功次数排前十

# %% [markdown]
# # 策略
# 看来后面得学习pandas了。这个还是非常之有必要的

# %%
import numpy as np
import pandas as pd

#学习pandas，这个才是最重要的事情
s = pd.Series([12,4,3,5],index=[1,2,3,4])#只能这样做了
print(s)

print(s.index)

print(s[1:3])#可以把s[1].s[2]打印出来

s[1]=15

#获取所有大于2的
print(s[s>2])

#整个数组可以直接使用四则运算以及其他基本运算
print(s/2)

#value_conuts()函数，不仅返回各个不同的元素，还计算每个元素在series中出现的次数

#isin()函数用来判断所属关系，[]里放的是一个范围
s.isin([0,5])

#isin()的理论是可以被复制的，

#series如何用作字典呢？ 直接把写好的字典放到里面就行了
mydict = {'red':2000, 'blue':1000, 'yellow':500, 'orange':1000}
myseries = pd.Series(mydict)
print(myseries)

#series对象之间的运算？
#只对标签相同的对象求和
#pandas的使用

# %%
'''
DataFrame对象是什么？
    是一种数据结构，就是工作表
    DataFrame有两个index,构建一个DataFrame需要一个字典，该字典，
'''
## 
import numpy as np
import pandas as pd

data = {'color':['blue','green','yellow','red','white'],
           'object':['ball','pen','pencil','paper','mug'],
            'price':[1.2,1.0,0.6,0.9,1.7]
       }
frame = pd.DataFrame(data)
print(frame)

#很多情况下，不是所有的列你都想
frame2 = pd.DataFrame(data,columns=['object','price'])
print(frame2)

#仍然可以添加纵坐标
frame3 = pd.DataFrame(data, index=['one','two','three','four','five'])
print(frame3)

#在DataFrame表格里可以添加新的Key和值，frame的数组的名字
frame4 = pd.DataFrame(data)
frame4['new'] = 12
frame4
# Out:
#     color  object  price
# 0    blue    ball    1.2
# 1   green     pen    1.0
# 2  yellow  pencil    0.6
# 3     red   paper    0.9
# 4   white     mug    1.7
#    object  price
# 0    ball    1.2
# 1     pen    1.0
# 2  pencil    0.6
# 3   paper    0.9
# 4     mug    1.7
#         color  object  price
# one      blue    ball    1.2
# two     green     pen    1.0
# three  yellow  pencil    0.6
# four      red   paper    0.9
# five    white     mug    1.7
#     color  object  price  new
# 0    blue    ball    1.2   12
# 1   green     pen    1.0   12
# 2  yellow  pencil    0.6   12
# 3     red   paper    0.9   12
# 4   white     mug    1.7   12

# %%
# DataFrame的构造函数？
#np.arrange(16).reshape((4,4)),
#arrange(16)表示生成0-15的随机数，reshape(4,4)表明生成一个4X4的表格

#column是横的，index是纵的。就是这样子。
#可以给column一个名字，也可以给index一个名字
import numpy as np
import pandas as pd


#需要添加表头
csvFrame = pd.read_csv('heroDone.csv', names=['hero','win','position','id'])
csvFrame

#再来说一下更为复杂的情况
#

# %%
import numpy as np
import pandas as pd

#用RegExp解析TXT文件
'''
有时要解析的文件不是以逗号或分号分隔开的，对于这种情况，正则表达式就会产生用场
正则表达式，把没有规律的空隔统一起来，非常地方便
'''

#读取部分数据，要怎么办？
'''
如何每隔两行把一个数进行累加呢？

最后把和插入到Series对象中去，小例子理解起来很简单

'''

frame1 = pd.DataFrame({'id':['ball', 'pencil', 'pen','mug','ashtray'],
                      'price':[12.33,11.44,33.21,13.23,33.62]})
print(frame1)

frame2 = pd.DataFrame({'id':['pencil','pencil','ball','pen'],
                      'color':['white','red','red','black']})
print(frame2)
frame3 = pd.merge(frame1,frame2,on='id')
print(frame3)
# Out:
#         id  price
# 0     ball  12.33
# 1   pencil  11.44
# 2      pen  33.21
# 3      mug  13.23
# 4  ashtray  33.62
#        id  color
# 0  pencil  white
# 1  pencil    red
# 2    ball    red
# 3     pen  black
#        id  price  color
# 0    ball  12.33    red
# 1  pencil  11.44  white
# 2  pencil  11.44    red
# 3     pen  33.21  black

# %%
#什么是根据索引合并？
#使用join方法，对索引进行合并
#join到底是干什么的？

#什么又是拼接呢？

#建立一个矩阵
array1 = ([
    [0,1,2],
    [6,7,8],
    [3,4,6]
])

array2  = np.arange(9).reshape((3,3))


array1
# Out:
# [[0, 1, 2], [6, 7, 8], [3, 4, 6]]

# %% [markdown]
# 如何使用numpy建立一个矩阵？
#
# ## 什么是拼接呢？
# 拼接，就是把两个相似矩阵给横向相加，变成一个新的矩阵
#
# 组合？
#
# ## pandas如何进行字符串处理？
# 1.使用join来进行拼接

# %%
text = '16 Bolton Avenue  , Boston'
txt = text.split(',')
print(txt)
tokens = [s.strip() for s in text.split(',')]# strip用来删除多余的空白字符
tokens
# Out:
# ['16 Bolton Avenue  ', ' Boston']
# ['16 Bolton Avenue', 'Boston']

# %%
frame = pd.DataFrame({'color':['white','red','green','red','green'],
                     'object':['pen','pencil','pencil','ashtray','pen'],
                     'price1':[5.56,4.20,1.30,0.56,2.75],
                     'price2':[4.75,4.12,1.60,0.75,3.15]})


#按照color给piece1进行分组
group1 = frame['price1'].groupby(frame['color'])
group1.groups
group1.mean()#是求平均值
group1.sum()#是求总和的
#print(frame)
#print(group1)
# Out:
# color
# green    2.025
# red      2.380
# white    5.560
# Name: price1, dtype: float64

# %%
import numpy as np
import pandas as pd

#导入csv文件
frame = pd.read_csv("heroDone.csv", names=['hero', 'win', 'position','userid'])

frame
# Out:
#               hero  win  position  userid
# 0     Fiddlesticks    0         4      98
# 1            Corki    1         3      72
# 2          Karthus    0         2      44
# 3            Kayle    0         3      92
# 4         Kassadin    0         2      75
# 5     Fiddlesticks    1         4      35
# 6              Jax    0         1      72
# 7               Yi    0         5      24
# 8            Corki    1         3      89
# 9           Irelia    1         1      31
# 10            Ashe    0         3      58
# 11         Trundle    1         1      97
# 12           Teemo    0         3      33
# 13          Anivia    0         2      24
# 14           Teemo    1         1      32
# 15           Teemo    0         3       5
# 16            Nunu    1         5       8
# 17         Karthus    1         2       5
# 18         Trundle    0         1      35
# 19         Evelynn    0         5      83
# 20            Nunu    0         5      44
# ...

# %%
import numpy as np
import pandas as pd

#导入csv文件
frame = pd.read_csv("heroDone.csv", names=['hero', 'win', 'position','userid'])

#按id分组计算出各个id的胜率
groups = frame['win'].groupby(frame['userid'])
#计算出来后，得到排名前10的选手
groups.mean().sort_values(ascending=False).head(10)
#把userid导入到ids[]数组中
# Out:
# userid
# 52    0.621053
# 75    0.608696
# 54    0.601942
# 86    0.585106
# 1     0.580952
# 65    0.574468
# 87    0.574074
# 92    0.572917
# 13    0.567308
# 78    0.565657
# Name: win, dtype: float64

# %%
import numpy as np
import pandas as pd

#导入csv文件
frame1 = pd.read_csv("heroDone.csv", names=['hero', 'win', 'position','userid'])

#按id分组计算出各个id的胜率
groups = frame['win'].groupby(frame['userid'])
#计算出来后，得到排名前10的选手,输出为一个csv文件
mostTen = groups.mean().sort_values(ascending=False).head(10)
#把userid导入到ids[]数组中
mostTen.index
#画一个图表，柱形图，将前10的胜率给做出来

#按上面的userid筛选出一个新的表，只有这10个id
#print(frame1.userid[98])

#groupby是可以按行来进行分类汇总的。
frame1['win'].groupby(frame1.userid == (mostTen.index[1]))
print(mostTen.index)
#按照id进行筛选,并且重新设定index
frame2 = frame[frame1.userid.isin(mostTen.index)].sort_values(by='userid',ascending=True)
frame2
# Out:
# Int64Index([52, 75, 54, 86, 1, 65, 87, 92, 13, 78], dtype='int64', name='userid')
#               hero  win  position  userid
# 5039        Irelia    1         1       1
# 3769         Annie    1         2       1
# 6465        Irelia    1         1       1
# 3762      Kassadin    1         2       1
# 6481         Amumu    0         5       1
# 6577            Yi    0         5       1
# 824             Yi    1         5       1
# 3403         Annie    1         2       1
# 6610  Fiddlesticks    0         4       1
# 6625         Teemo    1         2       1
# 6648     Gangplank    1         1       1
# 6703       ChoGath    1         2       1
# 778      Gangplank    1         1       1
# 6841         Kayle    0         1       1
# 6897        Anivia    0         2       1
# 724        Evelynn    1         5       1
# 7109         Annie    0         2       1
# 1628      Kassadin    1         2       1
# 7215         Teemo    1         2       1
# ...

# %%
按具体某一个列进行groupby的都是series,
python中布尔值要大写
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-b8d5f6b21890> in <module>()
# ----> 1 按具体某一个列进行groupby的都是series,
#       2 python中布尔值要大写
#
# NameError: name '按具体某一个列进行groupby的都是series' is not defined

# %%
#import numpy as np
import pandas as pd

#导入csv文件
frame1 = pd.read_csv("heroDone.csv", names=['hero', 'win', 'position','userid'])

#按id分组计算出各个id的胜率
groups = frame1['win'].groupby(frame1['userid'])
#计算出来后，得到排名前10的选手,输出为一个csv文件
mostTen = groups.mean().sort_values(ascending=False).head(10)
#把userid导入到ids[]数组中
mostTen.index
#画一个图表，柱形图，将前10的胜率给做出来

#按上面的userid筛选出一个新的表，只有这10个id
#print(frame1.userid[98])

#groupby是可以按行来进行分类汇总的。
#frame1['win'].groupby(frame1.userid == (mostTen.index[1]))
print(mostTen.index)
#按照id进行筛选,并且重新设定index,
frame2 = frame1[frame1.userid.isin(mostTen.index)].sort_values(by='userid',ascending=True)

#将frame2输出到CSV文件

#这10个人分别打什么位置最好
frame3 = frame2['win'].groupby([frame2.userid,frame2.position]).mean()

frame3.to_csv("whowhere1.csv",index=True,header=False)

type(frame3)#可知这个其实是一个series，必须要把series变为dataframe结构才行

#得出了一个表
frame4 = frame3.groupby(level=0,group_keys=False).nlargest(5)

#找到每个人最适合的位置
frame5 = frame3.groupby(level=0,group_keys=False).nlargest(1)
print(frame5)
frame5.to_csv("whowhere2.csv",index=True,header=False)
# Out:
# Int64Index([52, 75, 54, 86, 1, 65, 87, 92, 13, 78], dtype='int64', name='userid')
# userid  position
# 1       1           0.652174
# 13      5           0.666667
# 52      5           0.785714
# 54      5           0.800000
# 65      5           0.650000
# 75      1           0.724138
# 78      3           0.666667
# 86      1           0.695652
# 87      1           0.742857
# 92      4           0.636364
# Name: win, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np 

plt.plot([1,2,3,4])
plt.show()
